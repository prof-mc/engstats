# %% [markdown]
# # Lab 4 — Linear Regression
# Fitting and diagnosing a simple linear regression model with `engstats`.

# %%
# !pip install -i https://test.pypi.org/simple/ engstats
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...

# %%
import engstats as es
import matplotlib.pyplot as plt

# %%
df = es.load_dataset('concrete')
df.head()
# Out:
#    water_cement  age_days  strength_mpa
# 0         0.621        90         36.25
# 1         0.504        56         36.30
# 2         0.651        28         24.41
# 3         0.594        28         29.92
# 4         0.383        28         41.62

# %%
model = es.simple_linear_regression(df, x='water_cement', y='strength_mpa')
model.summary()
# Out:
#               coefficient       p_value   CI_lower   CI_upper
# term
# intercept       60.988425  4.402627e-45  57.004985  64.971865
# water_cement   -51.074012  2.063986e-22 -58.510138 -43.637887

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
es.plot_scatter_regression(df, x='water_cement', y='strength_mpa', ax=axes[0])
es.plot_residuals(model, ax=axes[1])
es.plot_qq(model, ax=axes[2])
plt.tight_layout()
