# %%
# !pip install -i https://test.pypi.org/simple/ -U engstats --extra-index-url https://pypi.org/simple/

# %%
# import seaborn as sns
import pandas as pd

df = pd.read_csv('Balloon.CSV')

# %%
import engstats as es

# %%
es.plot_stackeddot(df, 'Volume')
# Out:
# <Axes: title={'center': 'Stacked Dotplot of Volume'}, xlabel='Volume'>

# %%
es.plot_histogram(df['Volume'])
# Out:
# <Axes: title={'center': 'Histogram'}, xlabel='Value', ylabel='Count'>

# %%
es.plot_probability_order(df, 'Volume')
# Out:
# <Axes: title={'center': 'Normal Probability Plot: Volume'}, xlabel='Volume', ylabel='Percentile'>

# %%
es.plot_runplot(df, "Time Order", ["Volume"])
# Out:
# [<Axes: xlabel='Time Order', ylabel='Volume'>]

# %%
es.plot_runplot_split(df, "Time Order", "Volume",  "Operator")
# Out:
# <Axes: xlabel='Time Order', ylabel='Volume'>

# %%
es.plot_runplot_split(df, "Time Order", "Volume", "Color")
# Out:
# <Axes: xlabel='Time Order', ylabel='Volume'>

# %%
es.plot_scatter(df, "Height", "Volume")
# Out:
# <Axes: title={'center': 'Scatter Plot: Volume vs Height'}, xlabel='Height', ylabel='Volume'>

# %%
es.plot_scatter(df, "Height", "Volume", "Operator")
# Out:
# <Axes: title={'center': 'Scatter Plot: Volume vs Height'}, xlabel='Height', ylabel='Volume'>

# %%
es.plot_scatter(df, "Height", "Volume", "Color")
# Out:
# <Axes: title={'center': 'Scatter Plot: Volume vs Height'}, xlabel='Height', ylabel='Volume'>

# %%
es.plot_pareto(df, "Defects")
# Out:
# <Axes: title={'center': 'Pareto Plot: Defects'}, xlabel='Defects', ylabel='Count'>

# %%
es.plot_pairplot(df)

# %%
es.plot_side_by_side(df, ["Volume", "Time Order", "Operator"], style='individual')
# Out:
# <Axes: title={'center': 'Side-by-side individual plots'}, xlabel='Variable', ylabel='Value'>

# %%
es.plot_side_by_side(df, ["Volume", "Time Order", "Operator"], style='box')
# Out:
# <Axes: title={'center': 'Side-by-side box plots'}, xlabel='Variable', ylabel='Value'>
