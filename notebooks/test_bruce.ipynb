# %%
import engstats as es

# %%
df = es.load_dataset('concrete')

# %%
model = es.simple_linear_regression(df, x="water_cement", y="strength_mpa")
model.summary()
# Out:
# Number of observations (n): 80
# R² = 0.7056   Adj. R² = 0.7019
#               coefficient  SE coef  CI[0.025]  CI[0.975]  crit_value  \
# term
# Intercept         60.9884   2.0009    57.0050    64.9719     30.4808
# water_cement     -51.0740   3.7352   -58.5101   -43.6379    -13.6739
#
#                  p_value
# term
# Intercept     4.4026e-45
# water_cement  2.0640e-22
# ----------------------------------------
#                 df     sum_sq    mean_sq         F      PR(>F)
# water_cement   1.0  1866.1077  1866.1077  186.9745  2.0640e-22
# Residual      78.0   778.4827     9.9805       NaN         NaN
